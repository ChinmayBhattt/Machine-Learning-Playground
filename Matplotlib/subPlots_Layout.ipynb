# %%
import matplotlib.pyplot as plt

# %%
# plt.subplot(nrows, ncols, index)

x = [1,2,3,4]
y = [10,20,15,25]

plt.subplot(1,2,1) # 1row, 2colm, 1st subplot
plt.plot(x,y,color='green')
plt.title('Line Chart')

plt.subplot(1,2,2) # 1row, 2colm, 2nd subplot
plt.bar(x,y,color='blue')
plt.title('Bar Chart')

plt.tight_layout() ## automatic adjustment
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 x = [1,2,3,4]
#       4 y = [10,20,15,25]
# ----> 6 plt.subplot(1,2,1) # 1row, 2colm, 1st subplot
#       7 plt.plot(x,y,color='green')
#       8 plt.title('Line Chart')
#
# NameError: name 'plt' is not defined

# %%
# plt.subplot(nrows, ncols, figSize=(width, height), index)
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize = (10, 5))

x = [1,2,3,4]
y = [10,20,15,25]

ax[0].plot(x,y,color='red')
ax[0].set_title('Line Plot')

ax[1].bar(x,y,color='green')
ax[1].set_title('Bar Chart')

fig.suptitle('Comparison of Line & Bar Charts')
plt.tight_layout()
plt.show()
