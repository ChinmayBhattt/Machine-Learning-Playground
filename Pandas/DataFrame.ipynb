# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
import numpy as np
import pandas as pd

# %%
### Create Data Frame

# pd.DataFrame('chinmay.csv')
arr = np.array([112,234,43])
arr
# Out:
# array([112, 234,  43])
