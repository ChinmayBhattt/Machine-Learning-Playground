# %% [markdown]
# Python Pandas JSON
# - Read JSON (read_json)
# - To JSON (to_json)
# - JSON Normalize

# %%
# Nested Disctionary and convert string
data = '{"employee_name": "James" , "email": "James@gmail.com" , "job_profile": [{"title1": "Team Lead" , "title2": "Sr. Developer" ,}] ,}'

# %%
type(data)
# Out:
# str

# %%
import pandas as pd

# %%
pd.read_json(data)
# Out:
#   employee_name            email  \
# 0         James  James@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr. Develop...
